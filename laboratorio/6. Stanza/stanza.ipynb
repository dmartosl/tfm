# %%
# !pip install stanza
# Out:
# Requirement already satisfied: stanza in /usr/local/lib/python3.7/dist-packages (1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from stanza) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from stanza) (4.41.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from stanza) (3.12.4)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from stanza) (1.8.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stanza) (1.19.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2.10)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf->stanza) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf->stanza) (54.2.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.0->stanza) (3.7.4.3)

# %%
import stanza

stanza.download('es', verbose=False)
es_nlp = stanza.Pipeline('es', verbose=False, use_gpu=True)

# %%
import requests

file_url = 'https://raw.githubusercontent.com/dmartosl/tfm/master/data/SPACCC/corpus/S0004-06142005000400011-1.txt'
page = requests.get(file_url)
page.text
# Out:
# 'Varón de 66 años controlado en Consultas Externas por hipertrofia benigna de próstata. Presenta episodios de hematuria monosintomática autolimitada y urinocultivos negativos. En estudio ecográfico se observa ureteropielocaliectasia grado II de riñón derecho y en U.I.V. se objetiva anulación funcional de riñón derecho, motivo por el cuál, se practica nefrostomia percutánea derecha, que confirma el hallazgo urográfico. Ocho meses antes, est:udio ecográfico y U.I.V. sin hallazgos patológicos.\n\nEntre sus antecedentes personales cabe destacar: sin alergias conocidas. HTA. Diabetes Mellitus tipo II. Miocardiopatía hipertrófica. Aneurisma carotídeo intracerebral sin secuelas.\nLa exploración física practicada es la siguiente: Abdomen blando y depresible, no doloroso, no megalias, Fosas renales libres indoloras. Genitales externos sin signos patológicos. Tacto rectal compatible con HBP grado I-II. Se llevan a cabo las siguientes EXPLORACIONES COMPLEMENTARIAS:\nANALISIS: Glucemia 145 mg/dl, Creatinina 1.4 mg/dl. Resto de parámetros dentro de la normalidad.\nCITOLOGIA URINARIA: Compatible con carcinoma de células transicionales de bajo grado.\nPIELOGRAFIA DESCENDENTE a traves de Nefrostomia: Defecto de replección a nivel de uréter sacro-ilíaco derecho de aproximadamente 20 mm de longitud, con signos de infiltración de la pared.\n\nESTUDIO FUNCIONAL DE RIÑON DERECHO: Aclaramiento de Creatinina inferior a 5 ml/minuto.\nTAC ABDOMINO-PELVICO: Aneurisma de Aorta infrarrenal. Atrofia hidronefrótica de riñón derecho, sin visualizarse imágenes endoluminales intraureterales. Dudosas adenopatías paravesicales.\nAnte estos hallazgos y la sospecha de tumor de vías de uréter derecho, el paciente es intervenido quirúrgicamente practicándose nefroureterectomía radical derecha con evolución postoperatoria satisfactoria. El dictamen histopatológico de la pieza nos informa de pielonefritis crónica y cambios de arteriosclerosis, así como lesión inflamatoria ureteral que oblitera la luz con infiltrado de linfocitos en capas musculares, erosión de urotelio y presencia de Actinomices. Tras 9 años de seguimiento, el paciente mantiene una función renal aceptable (Creatinina sérica 2.1 mg/dl ) y es controlado por HBP sintomática.\n'

# %%
es_doc = es_nlp(page.text)
print(type(es_doc))
# Out:
# <class 'stanza.models.common.doc.Document'>

# %%
es_doc
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "Varón",
#       "lemma": "varón",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=0|end_char=5",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 4,
#       "deprel": "case",
#       "misc": "start_char=6|end_char=8",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": "66",
#       "lemma": "66",
#       "upos": "NUM",
#       "xpos": "NUM",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 4,
#       "deprel": "nummod",
#       "misc": "start_char=9|end_char=11",
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": "años",
#       "lemma": "año",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 1,
#       "deprel": "nmod",
#       "misc": "start_char=12|end_char=16",
#       "ner": "O"
#     },
#     {
#       "id": 5,
#       "text": "controlado",
#       "lemma": "controlar",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing|VerbForm=Part",
#       "head": 1,
#       "deprel": "amod",
#       "misc": "start_char=17|end_char=27",
#       "ner": "O"
#     },
#     {
#       "id": 6,
#       "text": "en",
#       "lemma": "en",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 7,
#       "deprel": "case",
#       "misc": "start_char=28|end_char=30",
#       "ner": "O"
#     },
#     {
#       "id": 7,
#       "text": "Consultas",
#       "lemma": "Consultas",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 5,
#       "deprel": "obl",
#       "misc": "start_char=31|end_char=40",
#       "ner": "B-MISC"
#     },
#     {
#       "id": 8,
#       "text": "Externas",
#       "lemma": "Externas",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 7,
#       "deprel": "flat",
#       "misc": "start_char=41|end_char=49",
#       "ner": "E-MISC"
#     },
#     {
#       "id": 9,
#       "text": "por",
#       "lemma": "por",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 10,
#       "deprel": "case",
#       "misc": "start_char=50|end_char=53",
#       "ner": "O"
#     },
#     {
#       "id": 10,
#       "text": "hipertrofia",
#       "lemma": "hipertrofia",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 5,
#       "deprel": "obl",
#       "misc": "start_char=54|end_char=65",
#       "ner": "O"
#     },
#     {
#       "id": 11,
#       "text": "benigna",
#       "lemma": "benigno",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 10,
#       "deprel": "amod",
#       "misc": "start_char=66|end_char=73",
#       "ner": "O"
#     },
#     {
#       "id": 12,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 13,
#       "deprel": "case",
#       "misc": "start_char=74|end_char=76",
#       "ner": "O"
#     },
#     {
#       "id": 13,
#       "text": "próstata",
#       "lemma": "próstata",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 10,
#       "deprel": "nmod",
#       "misc": "start_char=77|end_char=85",
#       "ner": "O"
#     },
#     {
#       "id": 14,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Peri",
#       "head": 1,
#       "deprel": "punct",
#       "misc": "start_char=85|end_char=86",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Presenta",
#       "lemma": "presentar",
#       "upos": "VERB",
#       "xpos": "VERB",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=87|end_char=95",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "episodios",
#       "lemma": "episodio",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 1,
#       "deprel": "obj",
#       "misc": "start_char=96|end_char=105",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 4,
#       "deprel": "case",
#       "misc": "start_char=106|end_char=108",
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": "hematuria",
#       "lemma": "hematuria",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 2,
#       "deprel": "nmod",
#       "misc": "start_char=109|end_char=118",
#       "ner": "O"
#     },
#     {
#       "id": 5,
#       "text": "monosintomática",
#       "lemma": "monosintomático",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 4,
#       "deprel": "amod",
#       "misc": "start_char=119|end_char=134",
#       "ner": "O"
#     },
#     {
#       "id": 6,
#       "text": "autolimitada",
#       "lemma": "autolimitado",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing|VerbForm=Part",
#       "head": 4,
#       "deprel": "amod",
#       "misc": "start_char=135|end_char=147",
#       "ner": "O"
#     },
#     {
#       "id": 7,
#       "text": "y",
#       "lemma": "y",
#       "upos": "CCONJ",
#       "xpos": "CCONJ",
#       "head": 8,
#       "deprel": "cc",
#       "misc": "start_char=148|end_char=149",
#       "ner": "O"
#     },
#     {
#       "id": 8,
#       "text": "urinocultivos",
#       "lemma": "urinocultivo",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 6,
#       "deprel": "conj",
#       "misc": "start_char=150|end_char=163",
#       "ner": "O"
#     },
#     {
#       "id": 9,
#       "text": "negativos",
#       "lemma": "negativo",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 8,
#       "deprel": "amod",
#       "misc": "start_char=164|end_char=173",
#       "ner": "O"
#     },
#     {
#       "id": 10,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Peri",
#       "head": 1,
#       "deprel": "punct",
#       "misc": "start_char=173|end_char=174",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "En",
#       "lemma": "en",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 2,
#       "deprel": "case",
#       "misc": "start_char=175|end_char=177",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "estudio",
#       "lemma": "estudio",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 5,
#       "deprel": "obl",
#       "misc": "start_char=178|end_char=185",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": "ecográfico",
#       "lemma": "ecográfico",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 2,
#       "deprel": "amod",
#       "misc": "start_char=186|end_char=196",
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": "se",
#       "lemma": "él",
#       "upos": "PRON",
#       "xpos": "PRON",
#       "feats": "Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes",
#       "head": 5,
#       "deprel": "expl:pass",
#       "misc": "start_char=197|end_char=199",
#       "ner": "O"
#     },
#     {
#       "id": 5,
#       "text": "observa",
#       "lemma": "observar",
#       "upos": "VERB",
#       "xpos": "VERB",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=200|end_char=207",
#       "ner": "O"
#     },
#     {
#       "id": 6,
#       "text": "ureteropielocaliectasia",
#       "lemma": "ureteropielocaliectasia",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Number=Sing",
#       "head": 7,
#       "deprel": "amod",
#       "misc": "start_char=208|end_char=231",
#       "ner": "O"
#     },
#     {
#       "id": 7,
#       "text": "grado",
#       "lemma": "grado",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 5,
#       "deprel": "nsubj",
#       "misc": "start_char=232|end_char=237",
#       "ner": "O"
#     },
#     {
#       "id": 8,
#       "text": "II",
#       "lemma": "II",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 7,
#       "deprel": "appos",
#       "misc": "start_char=238|end_char=240",
#       "ner": "O"
#     },
#     {
#       "id": 9,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 10,
#       "deprel": "case",
#       "misc": "start_char=241|end_char=243",
#       "ner": "O"
#     },
#     {
#       "id": 10,
#       "text": "riñón",
#       "lemma": "riñón",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 7,
#       "deprel": "nmod",
#       "misc": "start_char=244|end_char=249",
#       "ner": "O"
#     },
#     {
#       "id": 11,
#       "text": "derecho",
#       "lemma": "derecho",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 10,
#       "deprel": "amod",
#       "misc": "start_char=250|end_char=257",
#       "ner": "O"
#     },
#     {
#       "id": 12,
#       "text": "y",
#       "lemma": "y",
#       "upos": "CCONJ",
#       "xpos": "CCONJ",
#       "head": 17,
#       "deprel": "cc",
#       "misc": "start_char=258|end_char=259",
#       "ner": "O"
#     },
#     {
#       "id": 13,
#       "text": "en",
#       "lemma": "en",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 14,
#       "deprel": "case",
#       "misc": "start_char=260|end_char=262",
#       "ner": "O"
#     },
#     {
#       "id": 14,
#       "text": "U.I.V.",
#       "lemma": "U.I.V.",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 17,
#       "deprel": "nmod",
#       "misc": "start_char=263|end_char=269",
#       "ner": "S-MISC"
#     },
#     {
#       "id": 15,
#       "text": "se",
#       "lemma": "él",
#       "upos": "PRON",
#       "xpos": "PRON",
#       "feats": "Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes",
#       "head": 17,
#       "deprel": "amod",
#       "misc": "start_char=270|end_char=272",
#       "ner": "O"
#     },
#     {
#       "id": 16,
#       "text": "objetiva",
#       "lemma": "objetivo",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 17,
#       "deprel": "amod",
#       "misc": "start_char=273|end_char=281",
#       "ner": "O"
#     },
#     {
#       "id": 17,
#       "text": "anulación",
#       "lemma": "anulación",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 5,
#       "deprel": "conj",
#       "misc": "start_char=282|end_char=291",
#       "ner": "O"
#     },
#     {
#       "id": 18,
#       "text": "funcional",
#       "lemma": "funcional",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Number=Sing",
#       "head": 17,
#       "deprel": "amod",
#       "misc": "start_char=292|end_char=301",
#       "ner": "O"
#     },
#     {
#       "id": 19,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 20,
#       "deprel": "case",
#       "misc": "start_char=302|end_char=304",
#       "ner": "O"
#     },
#     {
#       "id": 20,
#       "text": "riñón",
#       "lemma": "riñón",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 17,
#       "deprel": "nmod",
#       "misc": "start_char=305|end_char=310",
#       "ner": "O"
#     },
#     {
#       "id": 21,
#       "text": "derecho",
#       "lemma": "derecho",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 20,
#       "deprel": "amod",
#       "misc": "start_char=311|end_char=318",
#       "ner": "O"
#     },
#     {
#       "id": 22,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Comm",
#       "head": 23,
#       "deprel": "punct",
#       "misc": "start_char=318|end_char=319",
#       "ner": "O"
#     },
#     {
#       "id": 23,
#       "text": "motivo",
#       "lemma": "motivo",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 17,
#       "deprel": "appos",
#       "misc": "start_char=320|end_char=326",
#       "ner": "O"
#     },
#     {
#       "id": 24,
#       "text": "por",
#       "lemma": "por",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 26,
#       "deprel": "case",
#       "misc": "start_char=327|end_char=330",
#       "ner": "O"
#     },
#     {
#       "id": 25,
#       "text": "el",
#       "lemma": "el",
#       "upos": "DET",
#       "xpos": "DET",
#       "feats": "Definite=Def|Gender=Masc|Number=Sing|PronType=Art",
#       "head": 26,
#       "deprel": "det",
#       "misc": "start_char=331|end_char=333",
#       "ner": "O"
#     },
#     {
#       "id": 26,
#       "text": "cuál",
#       "lemma": "cuál",
#       "upos": "PRON",
#       "xpos": "PRON",
#       "feats": "Number=Sing|PronType=Int,Rel",
#       "head": 29,
#       "deprel": "obl",
#       "misc": "start_char=334|end_char=338",
#       "ner": "O"
#     },
#     {
#       "id": 27,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Comm",
#       "head": 23,
#       "deprel": "punct",
#       "misc": "start_char=338|end_char=339",
#       "ner": "O"
#     },
#     {
#       "id": 28,
#       "text": "se",
#       "lemma": "él",
#       "upos": "PRON",
#       "xpos": "PRON",
#       "feats": "Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes",
#       "head": 29,
#       "deprel": "expl:pass",
#       "misc": "start_char=340|end_char=342",
#       "ner": "O"
#     },
#     {
#       "id": 29,
#       "text": "practica",
#       "lemma": "practicar",
#       "upos": "VERB",
#       "xpos": "VERB",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 23,
#       "deprel": "acl",
#       "misc": "start_char=343|end_char=351",
#       "ner": "O"
#     },
#     {
#       "id": 30,
#       "text": "nefrostomia",
#       "lemma": "nefrostomia",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 29,
#       "deprel": "nsubj",
#       "misc": "start_char=352|end_char=363",
#       "ner": "O"
#     },
#     {
#       "id": 31,
#       "text": "percutánea",
#       "lemma": "percutáneo",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 30,
#       "deprel": "amod",
#       "misc": "start_char=364|end_char=374",
#       "ner": "O"
#     },
#     {
#       "id": 32,
#       "text": "derecha",
#       "lemma": "derecho",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 30,
#       "deprel": "amod",
#       "misc": "start_char=375|end_char=382",
#       "ner": "O"
#     },
#     {
#       "id": 33,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Comm",
#       "head": 35,
#       "deprel": "punct",
#       "misc": "start_char=382|end_char=383",
#       "ner": "O"
#     },
#     {
#       "id": 34,
#       "text": "que",
#       "lemma": "que",
#       "upos": "PRON",
#       "xpos": "PRON",
#       "feats": "PronType=Int,Rel",
#       "head": 35,
#       "deprel": "nsubj",
#       "misc": "start_char=384|end_char=387",
#       "ner": "O"
#     },
#     {
#       "id": 35,
#       "text": "confirma",
#       "lemma": "confirmar",
#       "upos": "VERB",
#       "xpos": "VERB",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 30,
#       "deprel": "acl",
#       "misc": "start_char=388|end_char=396",
#       "ner": "O"
#     },
#     {
#       "id": 36,
#       "text": "el",
#       "lemma": "el",
#       "upos": "DET",
#       "xpos": "DET",
#       "feats": "Definite=Def|Gender=Masc|Number=Sing|PronType=Art",
#       "head": 37,
#       "deprel": "det",
#       "misc": "start_char=397|end_char=399",
#       "ner": "O"
#     },
#     {
#       "id": 37,
#       "text": "hallazgo",
#       "lemma": "hallazgo",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 35,
#       "deprel": "obj",
#       "misc": "start_char=400|end_char=408",
#       "ner": "O"
#     },
#     {
#       "id": 38,
#       "text": "urográfico",
#       "lemma": "urográfico",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 37,
#       "deprel": "amod",
#       "misc": "start_char=409|end_char=419",
#       "ner": "O"
#     },
#     {
#       "id": 39,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Peri",
#       "head": 5,
#       "deprel": "punct",
#       "misc": "start_char=419|end_char=420",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Ocho",
#       "lemma": "ocho",
#       "upos": "NUM",
#       "xpos": "NUM",
#       "feats": "NumType=Card|Number=Plur",
#       "head": 2,
#       "deprel": "nummod",
#       "misc": "start_char=421|end_char=425",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "meses",
#       "lemma": "mes",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 3,
#       "deprel": "obl",
#       "misc": "start_char=426|end_char=431",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": "antes",
#       "lemma": "antes",
#       "upos": "ADV",
#       "xpos": "ADV",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=432|end_char=437",
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Comm",
#       "head": 3,
#       "deprel": "punct",
#       "misc": "start_char=437|end_char=438",
#       "ner": "O"
#     },
#     {
#       "id": 5,
#       "text": "est",
#       "lemma": "est",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "head": 3,
#       "deprel": "obl",
#       "misc": "start_char=439|end_char=442",
#       "ner": "O"
#     },
#     {
#       "id": 6,
#       "text": ":",
#       "lemma": ":",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Colo",
#       "head": 7,
#       "deprel": "punct",
#       "misc": "start_char=442|end_char=443",
#       "ner": "O"
#     },
#     {
#       "id": 7,
#       "text": "udio",
#       "lemma": "udio",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 5,
#       "deprel": "appos",
#       "misc": "start_char=443|end_char=447",
#       "ner": "O"
#     },
#     {
#       "id": 8,
#       "text": "ecográfico",
#       "lemma": "ecográfico",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 7,
#       "deprel": "amod",
#       "misc": "start_char=448|end_char=458",
#       "ner": "O"
#     },
#     {
#       "id": 9,
#       "text": "y",
#       "lemma": "y",
#       "upos": "CCONJ",
#       "xpos": "CCONJ",
#       "head": 10,
#       "deprel": "cc",
#       "misc": "start_char=459|end_char=460",
#       "ner": "O"
#     },
#     {
#       "id": 10,
#       "text": "U.I.V.",
#       "lemma": "U.I.V.",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 7,
#       "deprel": "conj",
#       "misc": "start_char=461|end_char=467",
#       "ner": "S-ORG"
#     },
#     {
#       "id": 11,
#       "text": "sin",
#       "lemma": "sin",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 12,
#       "deprel": "case",
#       "misc": "start_char=468|end_char=471",
#       "ner": "O"
#     },
#     {
#       "id": 12,
#       "text": "hallazgos",
#       "lemma": "hallazgo",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 7,
#       "deprel": "nmod",
#       "misc": "start_char=472|end_char=481",
#       "ner": "O"
#     },
#     {
#       "id": 13,
#       "text": "patológicos",
#       "lemma": "patológico",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 12,
#       "deprel": "amod",
#       "misc": "start_char=482|end_char=493",
#       "ner": "O"
#     },
#     {
#       "id": 14,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Peri",
#       "head": 2,
#       "deprel": "punct",
#       "misc": "start_char=493|end_char=494",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Entre",
#       "lemma": "entre",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 3,
#       "deprel": "case",
#       "misc": "start_char=496|end_char=501",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "sus",
#       "lemma": "su",
#       "upos": "DET",
#       "xpos": "DET",
#       "feats": "Number=Plur|Person=3|Poss=Yes|PronType=Prs",
#       "head": 3,
#       "deprel": "det",
#       "misc": "start_char=502|end_char=505",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": "antecedentes",
#       "lemma": "antecedente",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 5,
#       "deprel": "obl",
#       "misc": "start_char=506|end_char=518",
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": "personales",
#       "lemma": "personal",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Number=Plur",
#       "head": 3,
#       "deprel": "amod",
#       "misc": "start_char=519|end_char=529",
#       "ner": "O"
#     },
#     {
#       "id": 5,
#       "text": "cabe",
#       "lemma": "caber",
#       "upos": "VERB",
#       "xpos": "VERB",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=530|end_char=534",
#       "ner": "O"
#     },
#     {
#       "id": 6,
#       "text": "destacar",
#       "lemma": "destacar",
#       "upos": "VERB",
#       "xpos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 5,
#       "deprel": "csubj",
#       "misc": "start_char=535|end_char=543",
#       "ner": "O"
#     },
#     {
#       "id": 7,
#       "text": ":",
#       "lemma": ":",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Colo",
#       "head": 9,
#       "deprel": "punct",
#       "misc": "start_char=543|end_char=544",
#       "ner": "O"
#     },
#     {
#       "id": 8,
#       "text": "sin",
#       "lemma": "sin",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 9,
#       "deprel": "case",
#       "misc": "start_char=545|end_char=548",
#       "ner": "O"
#     },
#     {
#       "id": 9,
#       "text": "alergias",
#       "lemma": "alergia",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 6,
#       "deprel": "obl",
#       "misc": "start_char=549|end_char=557",
#       "ner": "O"
#     },
#     {
#       "id": 10,
#       "text": "conocidas",
#       "lemma": "conocido",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur|VerbForm=Part",
#       "head": 9,
#       "deprel": "amod",
#       "misc": "start_char=558|end_char=567",
#       "ner": "O"
#     },
#     {
#       "id": 11,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Peri",
#       "head": 5,
#       "deprel": "punct",
#       "misc": "start_char=567|end_char=568",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "HTA",
#       "lemma": "HTA",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=569|end_char=572",
#       "ner": "S-MISC"
#     },
#     {
#       "id": 2,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Peri",
#       "head": 1,
#       "deprel": "punct",
#       "misc": "start_char=572|end_char=573",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Diabetes",
#       "lemma": "Diabetes",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=574|end_char=582",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "Mellitus",
#       "lemma": "Mellitus",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 1,
#       "deprel": "flat",
#       "misc": "start_char=583|end_char=591",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": "tipo",
#       "lemma": "tipo",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 1,
#       "deprel": "appos",
#       "misc": "start_char=592|end_char=596",
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": "II",
#       "lemma": "II",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 1,
#       "deprel": "flat",
#       "misc": "start_char=597|end_char=599",
#       "ner": "O"
#     },
#     {
#       "id": 5,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Peri",
#       "head": 1,
#       "deprel": "punct",
#       "misc": "start_char=599|end_char=600",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Miocardiopatía",
#       "lemma": "miocardiopatía",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=601|end_char=615",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "hipertrófica",
#       "lemma": "hipertrófico",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 1,
#       "deprel": "amod",
#       "misc": "start_char=616|end_char=628",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Peri",
#       "head": 1,
#       "deprel": "punct",
#       "misc": "start_char=628|end_char=629",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Aneurisma",
#       "lemma": "aneurisma",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=630|end_char=639",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "carotídeo",
#       "lemma": "carotídeo",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 1,
#       "deprel": "amod",
#       "misc": "start_char=640|end_char=649",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": "intracerebral",
#       "lemma": "intracerebral",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Number=Sing",
#       "head": 1,
#       "deprel": "amod",
#       "misc": "start_char=650|end_char=663",
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": "sin",
#       "lemma": "sin",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 5,
#       "deprel": "case",
#       "misc": "start_char=664|end_char=667",
#       "ner": "O"
#     },
#     {
#       "id": 5,
#       "text": "secuelas",
#       "lemma": "secuela",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 1,
#       "deprel": "nmod",
#       "misc": "start_char=668|end_char=676",
#       "ner": "O"
#     },
#     {
#       "id": 6,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Peri",
#       "head": 1,
#       "deprel": "punct",
#       "misc": "start_char=676|end_char=677",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "La",
#       "lemma": "el",
#       "upos": "DET",
#       "xpos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 2,
#       "deprel": "det",
#       "misc": "start_char=678|end_char=680",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "exploración",
#       "lemma": "exploración",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 7,
#       "deprel": "nsubj",
#       "misc": "start_char=681|end_char=692",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": "física",
#       "lemma": "físico",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 2,
#       "deprel": "amod",
#       "misc": "start_char=693|end_char=699",
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": "practicada",
#       "lemma": "practicado",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing|VerbForm=Part",
#       "head": 2,
#       "deprel": "amod",
#       "misc": "start_char=700|end_char=710",
#       "ner": "O"
#     },
#     {
#       "id": 5,
#       "text": "es",
#       "lemma": "ser",
#       "upos": "AUX",
#       "xpos": "AUX",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 7,
#       "deprel": "cop",
#       "misc": "start_char=711|end_char=713",
#       "ner": "O"
#     },
#     {
#       "id": 6,
#       "text": "la",
#       "lemma": "el",
#       "upos": "DET",
#       "xpos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 7,
#       "deprel": "det",
#       "misc": "start_char=714|end_char=716",
#       "ner": "O"
#     },
#     {
#       "id": 7,
#       "text": "siguiente",
#       "lemma": "siguiente",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=717|end_char=726",
#       "ner": "O"
#     },
#     {
#       "id": 8,
#       "text": ":",
#       "lemma": ":",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Colo",
#       "head": 9,
#       "deprel": "punct",
#       "misc": "start_char=726|end_char=727",
#       "ner": "O"
#     },
#     {
#       "id": 9,
#       "text": "Abdomen",
#       "lemma": "abdomen",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 7,
#       "deprel": "obj",
#       "misc": "start_char=728|end_char=735",
#       "ner": "O"
#     },
#     {
#       "id": 10,
#       "text": "blando",
#       "lemma": "blando",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 9,
#       "deprel": "amod",
#       "misc": "start_char=736|end_char=742",
#       "ner": "O"
#     },
#     {
#       "id": 11,
#       "text": "y",
#       "lemma": "y",
#       "upos": "CCONJ",
#       "xpos": "CCONJ",
#       "head": 12,
#       "deprel": "cc",
#       "misc": "start_char=743|end_char=744",
#       "ner": "O"
#     },
#     {
#       "id": 12,
#       "text": "depresible",
#       "lemma": "depresible",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Number=Sing",
#       "head": 10,
#       "deprel": "conj",
#       "misc": "start_char=745|end_char=755",
#       "ner": "O"
#     },
#     {
#       "id": 13,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Comm",
#       "head": 15,
#       "deprel": "punct",
#       "misc": "start_char=755|end_char=756",
#       "ner": "O"
#     },
#     {
#       "id": 14,
#       "text": "no",
#       "lemma": "no",
#       "upos": "ADV",
#       "xpos": "ADV",
#       "feats": "Polarity=Neg",
#       "head": 15,
#       "deprel": "advmod",
#       "misc": "start_char=757|end_char=759",
#       "ner": "O"
#     },
#     {
#       "id": 15,
#       "text": "doloroso",
#       "lemma": "doloroso",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 9,
#       "deprel": "amod",
#       "misc": "start_char=760|end_char=768",
#       "ner": "O"
#     },
#     {
#       "id": 16,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Comm",
#       "head": 15,
#       "deprel": "punct",
#       "misc": "start_char=768|end_char=769",
#       "ner": "O"
#     },
#     {
#       "id": 17,
#       "text": "no",
#       "lemma": "no",
#       "upos": "ADV",
#       "xpos": "ADV",
#       "feats": "Polarity=Neg",
#       "head": 18,
#       "deprel": "advmod",
#       "misc": "start_char=770|end_char=772",
#       "ner": "O"
#     },
#     {
#       "id": 18,
#       "text": "megalias",
#       "lemma": "megalias",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 9,
#       "deprel": "conj",
#       "misc": "start_char=773|end_char=781",
#       "ner": "O"
#     },
#     {
#       "id": 19,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Comm",
#       "head": 20,
#       "deprel": "punct",
#       "misc": "start_char=781|end_char=782",
#       "ner": "O"
#     },
#     {
#       "id": 20,
#       "text": "Fosas",
#       "lemma": "Fosas",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 9,
#       "deprel": "conj",
#       "misc": "start_char=783|end_char=788",
#       "ner": "O"
#     },
#     {
#       "id": 21,
#       "text": "renales",
#       "lemma": "renales",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 20,
#       "deprel": "flat",
#       "misc": "start_char=789|end_char=796",
#       "ner": "O"
#     },
#     {
#       "id": 22,
#       "text": "libres",
#       "lemma": "libre",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 20,
#       "deprel": "flat",
#       "misc": "start_char=797|end_char=803",
#       "ner": "O"
#     },
#     {
#       "id": 23,
#       "text": "indoloras",
#       "lemma": "indoloras",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 20,
#       "deprel": "flat",
#       "misc": "start_char=804|end_char=813",
#       "ner": "O"
#     },
#     {
#       "id": 24,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Peri",
#       "head": 7,
#       "deprel": "punct",
#       "misc": "start_char=813|end_char=814",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Genitales",
#       "lemma": "genital",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=815|end_char=824",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "externos",
#       "lemma": "externo",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 1,
#       "deprel": "amod",
#       "misc": "start_char=825|end_char=833",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": "sin",
#       "lemma": "sin",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 4,
#       "deprel": "case",
#       "misc": "start_char=834|end_char=837",
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": "signos",
#       "lemma": "signo",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 1,
#       "deprel": "nmod",
#       "misc": "start_char=838|end_char=844",
#       "ner": "O"
#     },
#     {
#       "id": 5,
#       "text": "patológicos",
#       "lemma": "patológico",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 4,
#       "deprel": "amod",
#       "misc": "start_char=845|end_char=856",
#       "ner": "O"
#     },
#     {
#       "id": 6,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Peri",
#       "head": 1,
#       "deprel": "punct",
#       "misc": "start_char=856|end_char=857",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Tacto",
#       "lemma": "Tacto",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=858|end_char=863",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "rectal",
#       "lemma": "rectal",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Number=Sing",
#       "head": 1,
#       "deprel": "amod",
#       "misc": "start_char=864|end_char=870",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": "compatible",
#       "lemma": "compatible",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Number=Sing",
#       "head": 1,
#       "deprel": "amod",
#       "misc": "start_char=871|end_char=881",
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": "con",
#       "lemma": "con",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 5,
#       "deprel": "case",
#       "misc": "start_char=882|end_char=885",
#       "ner": "O"
#     },
#     {
#       "id": 5,
#       "text": "HBP",
#       "lemma": "HBP",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 3,
#       "deprel": "nmod",
#       "misc": "start_char=886|end_char=889",
#       "ner": "O"
#     },
#     {
#       "id": 6,
#       "text": "grado",
#       "lemma": "grado",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 5,
#       "deprel": "flat",
#       "misc": "start_char=890|end_char=895",
#       "ner": "O"
#     },
#     {
#       "id": 7,
#       "text": "I-II",
#       "lemma": "I-II",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 5,
#       "deprel": "flat",
#       "misc": "start_char=896|end_char=900",
#       "ner": "O"
#     },
#     {
#       "id": 8,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Peri",
#       "head": 1,
#       "deprel": "punct",
#       "misc": "start_char=900|end_char=901",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Se",
#       "lemma": "él",
#       "upos": "PRON",
#       "xpos": "PRON",
#       "feats": "Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes",
#       "head": 2,
#       "deprel": "expl:pass",
#       "misc": "start_char=902|end_char=904",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "llevan",
#       "lemma": "llevar",
#       "upos": "VERB",
#       "xpos": "VERB",
#       "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=905|end_char=911",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": "a",
#       "lemma": "a",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 4,
#       "deprel": "case",
#       "misc": "start_char=912|end_char=913",
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": "cabo",
#       "lemma": "cabo",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 2,
#       "deprel": "compound",
#       "misc": "start_char=914|end_char=918",
#       "ner": "O"
#     },
#     {
#       "id": 5,
#       "text": "las",
#       "lemma": "el",
#       "upos": "DET",
#       "xpos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Plur|PronType=Art",
#       "head": 7,
#       "deprel": "det",
#       "misc": "start_char=919|end_char=922",
#       "ner": "O"
#     },
#     {
#       "id": 6,
#       "text": "siguientes",
#       "lemma": "siguiente",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Number=Plur",
#       "head": 7,
#       "deprel": "amod",
#       "misc": "start_char=923|end_char=933",
#       "ner": "O"
#     },
#     {
#       "id": 7,
#       "text": "EXPLORACIONES",
#       "lemma": "exploración",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 2,
#       "deprel": "nsubj",
#       "misc": "start_char=934|end_char=947",
#       "ner": "O"
#     },
#     {
#       "id": 8,
#       "text": "COMPLEMENTARIAS",
#       "lemma": "complementario",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 7,
#       "deprel": "amod",
#       "misc": "start_char=948|end_char=963",
#       "ner": "O"
#     },
#     {
#       "id": 9,
#       "text": ":",
#       "lemma": ":",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Colo",
#       "head": 10,
#       "deprel": "punct",
#       "misc": "start_char=963|end_char=964",
#       "ner": "O"
#     },
#     {
#       "id": 10,
#       "text": "ANALISIS",
#       "lemma": "analisis",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 7,
#       "deprel": "appos",
#       "misc": "start_char=965|end_char=973",
#       "ner": "O"
#     },
#     {
#       "id": 11,
#       "text": ":",
#       "lemma": ":",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Colo",
#       "head": 12,
#       "deprel": "punct",
#       "misc": "start_char=973|end_char=974",
#       "ner": "O"
#     },
#     {
#       "id": 12,
#       "text": "Glucemia",
#       "lemma": "Glucemia",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 10,
#       "deprel": "appos",
#       "misc": "start_char=975|end_char=983",
#       "ner": "O"
#     },
#     {
#       "id": 13,
#       "text": "145",
#       "lemma": "145",
#       "upos": "NUM",
#       "xpos": "NUM",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 14,
#       "deprel": "nummod",
#       "misc": "start_char=984|end_char=987",
#       "ner": "O"
#     },
#     {
#       "id": 14,
#       "text": "mg/dl",
#       "lemma": "mg/dl",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc",
#       "head": 12,
#       "deprel": "appos",
#       "misc": "start_char=988|end_char=993",
#       "ner": "O"
#     },
#     {
#       "id": 15,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Comm",
#       "head": 16,
#       "deprel": "punct",
#       "misc": "start_char=993|end_char=994",
#       "ner": "O"
#     },
#     {
#       "id": 16,
#       "text": "Creatinina",
#       "lemma": "Creatinina",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 12,
#       "deprel": "conj",
#       "misc": "start_char=995|end_char=1005",
#       "ner": "O"
#     },
#     {
#       "id": 17,
#       "text": "1.4",
#       "lemma": "1.4",
#       "upos": "NUM",
#       "xpos": "NUM",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 18,
#       "deprel": "nummod",
#       "misc": "start_char=1006|end_char=1009",
#       "ner": "O"
#     },
#     {
#       "id": 18,
#       "text": "mg/dl",
#       "lemma": "mg/dl",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc",
#       "head": 16,
#       "deprel": "appos",
#       "misc": "start_char=1010|end_char=1015",
#       "ner": "O"
#     },
#     {
#       "id": 19,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Peri",
#       "head": 2,
#       "deprel": "punct",
#       "misc": "start_char=1015|end_char=1016",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Resto",
#       "lemma": "resto",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=1017|end_char=1022",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 3,
#       "deprel": "case",
#       "misc": "start_char=1023|end_char=1025",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": "parámetros",
#       "lemma": "parámetro",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 1,
#       "deprel": "nmod",
#       "misc": "start_char=1026|end_char=1036",
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": "dentro",
#       "lemma": "dentro",
#       "upos": "ADV",
#       "xpos": "ADV",
#       "head": 1,
#       "deprel": "advmod",
#       "misc": "start_char=1037|end_char=1043",
#       "ner": "O"
#     },
#     {
#       "id": 5,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 7,
#       "deprel": "case",
#       "misc": "start_char=1044|end_char=1046",
#       "ner": "O"
#     },
#     {
#       "id": 6,
#       "text": "la",
#       "lemma": "el",
#       "upos": "DET",
#       "xpos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 7,
#       "deprel": "det",
#       "misc": "start_char=1047|end_char=1049",
#       "ner": "O"
#     },
#     {
#       "id": 7,
#       "text": "normalidad",
#       "lemma": "normalidad",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 4,
#       "deprel": "obl",
#       "misc": "start_char=1050|end_char=1060",
#       "ner": "O"
#     },
#     {
#       "id": 8,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Peri",
#       "head": 1,
#       "deprel": "punct",
#       "misc": "start_char=1060|end_char=1061",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "CITOLOGIA",
#       "lemma": "citologia",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=1062|end_char=1071",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "URINARIA",
#       "lemma": "URINARIA",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 1,
#       "deprel": "appos",
#       "misc": "start_char=1072|end_char=1080",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": ":",
#       "lemma": ":",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Colo",
#       "head": 4,
#       "deprel": "punct",
#       "misc": "start_char=1080|end_char=1081",
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": "Compatible",
#       "lemma": "Compatible",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 1,
#       "deprel": "appos",
#       "misc": "start_char=1082|end_char=1092",
#       "ner": "O"
#     },
#     {
#       "id": 5,
#       "text": "con",
#       "lemma": "con",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 6,
#       "deprel": "case",
#       "misc": "start_char=1093|end_char=1096",
#       "ner": "O"
#     },
#     {
#       "id": 6,
#       "text": "carcinoma",
#       "lemma": "carcinoma",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 4,
#       "deprel": "nmod",
#       "misc": "start_char=1097|end_char=1106",
#       "ner": "O"
#     },
#     {
#       "id": 7,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 8,
#       "deprel": "case",
#       "misc": "start_char=1107|end_char=1109",
#       "ner": "O"
#     },
#     {
#       "id": 8,
#       "text": "células",
#       "lemma": "célula",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 6,
#       "deprel": "nmod",
#       "misc": "start_char=1110|end_char=1117",
#       "ner": "O"
#     },
#     {
#       "id": 9,
#       "text": "transicionales",
#       "lemma": "transicional",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Number=Plur",
#       "head": 8,
#       "deprel": "amod",
#       "misc": "start_char=1118|end_char=1132",
#       "ner": "O"
#     },
#     {
#       "id": 10,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 12,
#       "deprel": "case",
#       "misc": "start_char=1133|end_char=1135",
#       "ner": "O"
#     },
#     {
#       "id": 11,
#       "text": "bajo",
#       "lemma": "bajo",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 12,
#       "deprel": "case",
#       "misc": "start_char=1136|end_char=1140",
#       "ner": "O"
#     },
#     {
#       "id": 12,
#       "text": "grado",
#       "lemma": "grado",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 8,
#       "deprel": "nmod",
#       "misc": "start_char=1141|end_char=1146",
#       "ner": "O"
#     },
#     {
#       "id": 13,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Peri",
#       "head": 1,
#       "deprel": "punct",
#       "misc": "start_char=1146|end_char=1147",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "PIELOGRAFIA",
#       "lemma": "PIELLGGAFIA",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=1148|end_char=1159",
#       "ner": "B-MISC"
#     },
#     {
#       "id": 2,
#       "text": "DESCENDENTE",
#       "lemma": "DESCENDENTE",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Number=Sing",
#       "head": 1,
#       "deprel": "amod",
#       "misc": "start_char=1160|end_char=1171",
#       "ner": "E-MISC"
#     },
#     {
#       "id": 3,
#       "text": "a",
#       "lemma": "a",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 6,
#       "deprel": "case",
#       "misc": "start_char=1172|end_char=1173",
#       "ner": "O"
#     },
#     {
#       "id": 4,
# ...
#       "ner": "O"
#     },
#     {
#       "id": 7,
#       "text": "nos",
#       "lemma": "yo",
#       "upos": "PRON",
#       "xpos": "PRON",
#       "feats": "Case=Dat|Number=Plur|Person=1|PrepCase=Npr|PronType=Prs",
#       "head": 8,
#       "deprel": "obj",
#       "misc": "start_char=1858|end_char=1861",
#       "ner": "O"
#     },
#     {
#       "id": 8,
#       "text": "informa",
#       "lemma": "informar",
#       "upos": "VERB",
#       "xpos": "VERB",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=1862|end_char=1869",
#       "ner": "O"
#     },
#     {
#       "id": 9,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 10,
#       "deprel": "case",
#       "misc": "start_char=1870|end_char=1872",
#       "ner": "O"
#     },
#     {
#       "id": 10,
#       "text": "pielonefritis",
#       "lemma": "pielonefritis",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem",
#       "head": 8,
#       "deprel": "obj",
#       "misc": "start_char=1873|end_char=1886",
#       "ner": "O"
#     },
#     {
#       "id": 11,
#       "text": "crónica",
#       "lemma": "crónica",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 10,
#       "deprel": "amod",
#       "misc": "start_char=1887|end_char=1894",
#       "ner": "O"
#     },
#     {
#       "id": 12,
#       "text": "y",
#       "lemma": "y",
#       "upos": "CCONJ",
#       "xpos": "CCONJ",
#       "head": 13,
#       "deprel": "cc",
#       "misc": "start_char=1895|end_char=1896",
#       "ner": "O"
#     },
#     {
#       "id": 13,
#       "text": "cambios",
#       "lemma": "cambio",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 10,
#       "deprel": "conj",
#       "misc": "start_char=1897|end_char=1904",
#       "ner": "O"
#     },
#     {
#       "id": 14,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 15,
#       "deprel": "case",
#       "misc": "start_char=1905|end_char=1907",
#       "ner": "O"
#     },
#     {
#       "id": 15,
#       "text": "arteriosclerosis",
#       "lemma": "arteriosclerosis",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem",
#       "head": 13,
#       "deprel": "nmod",
#       "misc": "start_char=1908|end_char=1924",
#       "ner": "O"
#     },
#     {
#       "id": 16,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Comm",
#       "head": 19,
#       "deprel": "punct",
#       "misc": "start_char=1924|end_char=1925",
#       "ner": "O"
#     },
#     {
#       "id": 17,
#       "text": "así",
#       "lemma": "así",
#       "upos": "ADV",
#       "xpos": "ADV",
#       "head": 19,
#       "deprel": "cc",
#       "misc": "start_char=1926|end_char=1929",
#       "ner": "O"
#     },
#     {
#       "id": 18,
#       "text": "como",
#       "lemma": "como",
#       "upos": "SCONJ",
#       "xpos": "SCONJ",
#       "head": 17,
#       "deprel": "fixed",
#       "misc": "start_char=1930|end_char=1934",
#       "ner": "O"
#     },
#     {
#       "id": 19,
#       "text": "lesión",
#       "lemma": "lesión",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 10,
#       "deprel": "conj",
#       "misc": "start_char=1935|end_char=1941",
#       "ner": "O"
#     },
#     {
#       "id": 20,
#       "text": "inflamatoria",
#       "lemma": "inflamatorio",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 19,
#       "deprel": "amod",
#       "misc": "start_char=1942|end_char=1954",
#       "ner": "O"
#     },
#     {
#       "id": 21,
#       "text": "ureteral",
#       "lemma": "ureteral",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Number=Sing",
#       "head": 19,
#       "deprel": "amod",
#       "misc": "start_char=1955|end_char=1963",
#       "ner": "O"
#     },
#     {
#       "id": 22,
#       "text": "que",
#       "lemma": "que",
#       "upos": "PRON",
#       "xpos": "PRON",
#       "feats": "PronType=Int,Rel",
#       "head": 23,
#       "deprel": "nsubj",
#       "misc": "start_char=1964|end_char=1967",
#       "ner": "O"
#     },
#     {
#       "id": 23,
#       "text": "oblitera",
#       "lemma": "obliterar",
#       "upos": "VERB",
#       "xpos": "VERB",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 19,
#       "deprel": "acl",
#       "misc": "start_char=1968|end_char=1976",
#       "ner": "O"
#     },
#     {
#       "id": 24,
#       "text": "la",
#       "lemma": "el",
#       "upos": "DET",
#       "xpos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 25,
#       "deprel": "det",
#       "misc": "start_char=1977|end_char=1979",
#       "ner": "O"
#     },
#     {
#       "id": 25,
#       "text": "luz",
#       "lemma": "luz",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 23,
#       "deprel": "obj",
#       "misc": "start_char=1980|end_char=1983",
#       "ner": "O"
#     },
#     {
#       "id": 26,
#       "text": "con",
#       "lemma": "con",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 27,
#       "deprel": "case",
#       "misc": "start_char=1984|end_char=1987",
#       "ner": "O"
#     },
#     {
#       "id": 27,
#       "text": "infiltrado",
#       "lemma": "infiltrado",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 25,
#       "deprel": "nmod",
#       "misc": "start_char=1988|end_char=1998",
#       "ner": "O"
#     },
#     {
#       "id": 28,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 29,
#       "deprel": "case",
#       "misc": "start_char=1999|end_char=2001",
#       "ner": "O"
#     },
#     {
#       "id": 29,
#       "text": "linfocitos",
#       "lemma": "linfocito",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 27,
#       "deprel": "nmod",
#       "misc": "start_char=2002|end_char=2012",
#       "ner": "O"
#     },
#     {
#       "id": 30,
#       "text": "en",
#       "lemma": "en",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 31,
#       "deprel": "case",
#       "misc": "start_char=2013|end_char=2015",
#       "ner": "O"
#     },
#     {
#       "id": 31,
#       "text": "capas",
#       "lemma": "capa",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 27,
#       "deprel": "nmod",
#       "misc": "start_char=2016|end_char=2021",
#       "ner": "O"
#     },
#     {
#       "id": 32,
#       "text": "musculares",
#       "lemma": "muscular",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Number=Plur",
#       "head": 31,
#       "deprel": "amod",
#       "misc": "start_char=2022|end_char=2032",
#       "ner": "O"
#     },
#     {
#       "id": 33,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Comm",
#       "head": 34,
#       "deprel": "punct",
#       "misc": "start_char=2032|end_char=2033",
#       "ner": "O"
#     },
#     {
#       "id": 34,
#       "text": "erosión",
#       "lemma": "erosión",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 27,
#       "deprel": "conj",
#       "misc": "start_char=2034|end_char=2041",
#       "ner": "O"
#     },
#     {
#       "id": 35,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 36,
#       "deprel": "case",
#       "misc": "start_char=2042|end_char=2044",
#       "ner": "O"
#     },
#     {
#       "id": 36,
#       "text": "urotelio",
#       "lemma": "urotelio",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 34,
#       "deprel": "nmod",
#       "misc": "start_char=2045|end_char=2053",
#       "ner": "O"
#     },
#     {
#       "id": 37,
#       "text": "y",
#       "lemma": "y",
#       "upos": "CCONJ",
#       "xpos": "CCONJ",
#       "head": 38,
#       "deprel": "cc",
#       "misc": "start_char=2054|end_char=2055",
#       "ner": "O"
#     },
#     {
#       "id": 38,
#       "text": "presencia",
#       "lemma": "presencia",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 27,
#       "deprel": "conj",
#       "misc": "start_char=2056|end_char=2065",
#       "ner": "O"
#     },
#     {
#       "id": 39,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 40,
#       "deprel": "case",
#       "misc": "start_char=2066|end_char=2068",
#       "ner": "O"
#     },
#     {
#       "id": 40,
#       "text": "Actinomices",
#       "lemma": "Actinomices",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 38,
#       "deprel": "nmod",
#       "misc": "start_char=2069|end_char=2080",
#       "ner": "S-MISC"
#     },
#     {
#       "id": 41,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Peri",
#       "head": 8,
#       "deprel": "punct",
#       "misc": "start_char=2080|end_char=2081",
#       "ner": "O"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Tras",
#       "lemma": "tras",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 3,
#       "deprel": "case",
#       "misc": "start_char=2082|end_char=2086",
#       "ner": "O"
#     },
#     {
#       "id": 2,
#       "text": "9",
#       "lemma": "9",
#       "upos": "NUM",
#       "xpos": "NUM",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 3,
#       "deprel": "nummod",
#       "misc": "start_char=2087|end_char=2088",
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": "años",
#       "lemma": "año",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 9,
#       "deprel": "obl",
#       "misc": "start_char=2089|end_char=2093",
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 5,
#       "deprel": "case",
#       "misc": "start_char=2094|end_char=2096",
#       "ner": "O"
#     },
#     {
#       "id": 5,
#       "text": "seguimiento",
#       "lemma": "seguimiento",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 3,
#       "deprel": "nmod",
#       "misc": "start_char=2097|end_char=2108",
#       "ner": "O"
#     },
#     {
#       "id": 6,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Comm",
#       "head": 3,
#       "deprel": "punct",
#       "misc": "start_char=2108|end_char=2109",
#       "ner": "O"
#     },
#     {
#       "id": 7,
#       "text": "el",
#       "lemma": "el",
#       "upos": "DET",
#       "xpos": "DET",
#       "feats": "Definite=Def|Gender=Masc|Number=Sing|PronType=Art",
#       "head": 8,
#       "deprel": "det",
#       "misc": "start_char=2110|end_char=2112",
#       "ner": "O"
#     },
#     {
#       "id": 8,
#       "text": "paciente",
#       "lemma": "paciente",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Number=Sing",
#       "head": 9,
#       "deprel": "nsubj",
#       "misc": "start_char=2113|end_char=2121",
#       "ner": "O"
#     },
#     {
#       "id": 9,
#       "text": "mantiene",
#       "lemma": "mantener",
#       "upos": "VERB",
#       "xpos": "VERB",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=2122|end_char=2130",
#       "ner": "O"
#     },
#     {
#       "id": 10,
#       "text": "una",
#       "lemma": "uno",
#       "upos": "DET",
#       "xpos": "DET",
#       "feats": "Definite=Ind|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 11,
#       "deprel": "det",
#       "misc": "start_char=2131|end_char=2134",
#       "ner": "O"
#     },
#     {
#       "id": 11,
#       "text": "función",
#       "lemma": "función",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 9,
#       "deprel": "obj",
#       "misc": "start_char=2135|end_char=2142",
#       "ner": "O"
#     },
#     {
#       "id": 12,
#       "text": "renal",
#       "lemma": "renal",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Number=Sing",
#       "head": 11,
#       "deprel": "amod",
#       "misc": "start_char=2143|end_char=2148",
#       "ner": "O"
#     },
#     {
#       "id": 13,
#       "text": "aceptable",
#       "lemma": "aceptable",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Number=Sing",
#       "head": 11,
#       "deprel": "amod",
#       "misc": "start_char=2149|end_char=2158",
#       "ner": "O"
#     },
#     {
#       "id": 14,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctSide=Ini|PunctType=Brck",
#       "head": 15,
#       "deprel": "punct",
#       "misc": "start_char=2159|end_char=2160",
#       "ner": "O"
#     },
#     {
#       "id": 15,
#       "text": "Creatinina",
#       "lemma": "Creatinina",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 11,
#       "deprel": "appos",
#       "misc": "start_char=2160|end_char=2170",
#       "ner": "O"
#     },
#     {
#       "id": 16,
#       "text": "sérica",
#       "lemma": "sérico",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 15,
#       "deprel": "amod",
#       "misc": "start_char=2171|end_char=2177",
#       "ner": "O"
#     },
#     {
#       "id": 17,
#       "text": "2.1",
#       "lemma": "2.1",
#       "upos": "NUM",
#       "xpos": "NUM",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 15,
#       "deprel": "appos",
#       "misc": "start_char=2178|end_char=2181",
#       "ner": "O"
#     },
#     {
#       "id": 18,
#       "text": "mg/dl",
#       "lemma": "mg/dl",
#       "upos": "NOUN",
#       "xpos": "NOUN",
#       "head": 15,
#       "deprel": "compound",
#       "misc": "start_char=2182|end_char=2187",
#       "ner": "O"
#     },
#     {
#       "id": 19,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctSide=Fin|PunctType=Brck",
#       "head": 15,
#       "deprel": "punct",
#       "misc": "start_char=2188|end_char=2189",
#       "ner": "O"
#     },
#     {
#       "id": 20,
#       "text": "y",
#       "lemma": "y",
#       "upos": "CCONJ",
#       "xpos": "CCONJ",
#       "head": 22,
#       "deprel": "cc",
#       "misc": "start_char=2190|end_char=2191",
#       "ner": "O"
#     },
#     {
#       "id": 21,
#       "text": "es",
#       "lemma": "ser",
#       "upos": "AUX",
#       "xpos": "AUX",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 22,
#       "deprel": "aux",
#       "misc": "start_char=2192|end_char=2194",
#       "ner": "O"
#     },
#     {
#       "id": 22,
#       "text": "controlado",
#       "lemma": "controlar",
#       "upos": "VERB",
#       "xpos": "VERB",
#       "feats": "Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part",
#       "head": 9,
#       "deprel": "conj",
#       "misc": "start_char=2195|end_char=2205",
#       "ner": "O"
#     },
#     {
#       "id": 23,
#       "text": "por",
#       "lemma": "por",
#       "upos": "ADP",
#       "xpos": "ADP",
#       "feats": "AdpType=Prep",
#       "head": 24,
#       "deprel": "case",
#       "misc": "start_char=2206|end_char=2209",
#       "ner": "O"
#     },
#     {
#       "id": 24,
#       "text": "HBP",
#       "lemma": "HBP",
#       "upos": "PROPN",
#       "xpos": "PROPN",
#       "head": 22,
#       "deprel": "obj",
#       "misc": "start_char=2210|end_char=2213",
#       "ner": "S-ORG"
#     },
#     {
#       "id": 25,
#       "text": "sintomática",
#       "lemma": "sintomático",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 24,
#       "deprel": "amod",
#       "misc": "start_char=2214|end_char=2225",
#       "ner": "O"
#     },
#     {
#       "id": 26,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "PUNCT",
#       "feats": "PunctType=Peri",
#       "head": 9,
#       "deprel": "punct",
#       "misc": "start_char=2225|end_char=2226",
#       "ner": "O"
#     }
#   ]
# ]

# %%
for i, sent in enumerate(es_doc.sentences):
    print("[Sentence {}]".format(i+1))
    for word in sent.words:
        print("{:12s}\t{:12s}\t{:6s}\t{:d}\t{:12s}".format(\
              word.text, word.lemma, word.pos, word.head, word.deprel))
    print("")
# Out:
# [Sentence 1]
# Varón       	varón       	NOUN  	0	root
# de          	de          	ADP   	4	case
# 66          	66          	NUM   	4	nummod
# años        	año         	NOUN  	1	nmod
# controlado  	controlar   	ADJ   	1	amod
# en          	en          	ADP   	7	case
# Consultas   	Consultas   	PROPN 	5	obl
# Externas    	Externas    	PROPN 	7	flat
# por         	por         	ADP   	10	case
# hipertrofia 	hipertrofia 	NOUN  	5	obl
# benigna     	benigno     	ADJ   	10	amod
# de          	de          	ADP   	13	case
# próstata    	próstata    	NOUN  	10	nmod
# .           	.           	PUNCT 	1	punct
#
# [Sentence 2]
# Presenta    	presentar   	VERB  	0	root
# episodios   	episodio    	NOUN  	1	obj
# de          	de          	ADP   	4	case
# hematuria   	hematuria   	NOUN  	2	nmod
# monosintomática	monosintomático	ADJ   	4	amod
# autolimitada	autolimitado	ADJ   	4	amod
# y           	y           	CCONJ 	8	cc
# urinocultivos	urinocultivo	ADJ   	6	conj
# negativos   	negativo    	ADJ   	8	amod
# .           	.           	PUNCT 	1	punct
#
# [Sentence 3]
# En          	en          	ADP   	2	case
# estudio     	estudio     	NOUN  	5	obl
# ecográfico  	ecográfico  	ADJ   	2	amod
# se          	él          	PRON  	5	expl:pass
# observa     	observar    	VERB  	0	root
# ureteropielocaliectasia	ureteropielocaliectasia	ADJ   	7	amod
# grado       	grado       	NOUN  	5	nsubj
# II          	II          	PROPN 	7	appos
# de          	de          	ADP   	10	case
# riñón       	riñón       	NOUN  	7	nmod
# derecho     	derecho     	ADJ   	10	amod
# y           	y           	CCONJ 	17	cc
# en          	en          	ADP   	14	case
# U.I.V.      	U.I.V.      	PROPN 	17	nmod
# se          	él          	PRON  	17	amod
# objetiva    	objetivo    	ADJ   	17	amod
# anulación   	anulación   	NOUN  	5	conj
# funcional   	funcional   	ADJ   	17	amod
# de          	de          	ADP   	20	case
# riñón       	riñón       	NOUN  	17	nmod
# derecho     	derecho     	ADJ   	20	amod
# ,           	,           	PUNCT 	23	punct
# motivo      	motivo      	NOUN  	17	appos
# por         	por         	ADP   	26	case
# el          	el          	DET   	26	det
# cuál        	cuál        	PRON  	29	obl
# ,           	,           	PUNCT 	23	punct
# se          	él          	PRON  	29	expl:pass
# practica    	practicar   	VERB  	23	acl
# nefrostomia 	nefrostomia 	NOUN  	29	nsubj
# percutánea  	percutáneo  	ADJ   	30	amod
# derecha     	derecho     	ADJ   	30	amod
# ,           	,           	PUNCT 	35	punct
# que         	que         	PRON  	35	nsubj
# confirma    	confirmar   	VERB  	30	acl
# el          	el          	DET   	37	det
# hallazgo    	hallazgo    	NOUN  	35	obj
# urográfico  	urográfico  	ADJ   	37	amod
# .           	.           	PUNCT 	5	punct
#
# [Sentence 4]
# Ocho        	ocho        	NUM   	2	nummod
# meses       	mes         	NOUN  	3	obl
# antes       	antes       	ADV   	0	root
# ,           	,           	PUNCT 	3	punct
# est         	est         	NOUN  	3	obl
# :           	:           	PUNCT 	7	punct
# udio        	udio        	NOUN  	5	appos
# ecográfico  	ecográfico  	ADJ   	7	amod
# y           	y           	CCONJ 	10	cc
# U.I.V.      	U.I.V.      	PROPN 	7	conj
# sin         	sin         	ADP   	12	case
# hallazgos   	hallazgo    	NOUN  	7	nmod
# patológicos 	patológico  	ADJ   	12	amod
# .           	.           	PUNCT 	2	punct
#
# [Sentence 5]
# Entre       	entre       	ADP   	3	case
# sus         	su          	DET   	3	det
# antecedentes	antecedente 	NOUN  	5	obl
# personales  	personal    	ADJ   	3	amod
# cabe        	caber       	VERB  	0	root
# destacar    	destacar    	VERB  	5	csubj
# :           	:           	PUNCT 	9	punct
# sin         	sin         	ADP   	9	case
# alergias    	alergia     	NOUN  	6	obl
# conocidas   	conocido    	ADJ   	9	amod
# .           	.           	PUNCT 	5	punct
#
# [Sentence 6]
# HTA         	HTA         	PROPN 	0	root
# .           	.           	PUNCT 	1	punct
#
# [Sentence 7]
# Diabetes    	Diabetes    	PROPN 	0	root
# Mellitus    	Mellitus    	PROPN 	1	flat
# tipo        	tipo        	NOUN  	1	appos
# II          	II          	PROPN 	1	flat
# .           	.           	PUNCT 	1	punct
#
# [Sentence 8]
# Miocardiopatía	miocardiopatía	NOUN  	0	root
# hipertrófica	hipertrófico	ADJ   	1	amod
# .           	.           	PUNCT 	1	punct
#
# [Sentence 9]
# Aneurisma   	aneurisma   	NOUN  	0	root
# carotídeo   	carotídeo   	ADJ   	1	amod
# intracerebral	intracerebral	ADJ   	1	amod
# sin         	sin         	ADP   	5	case
# secuelas    	secuela     	NOUN  	1	nmod
# .           	.           	PUNCT 	1	punct
#
# [Sentence 10]
# La          	el          	DET   	2	det
# exploración 	exploración 	NOUN  	7	nsubj
# física      	físico      	ADJ   	2	amod
# practicada  	practicado  	ADJ   	2	amod
# es          	ser         	AUX   	7	cop
# la          	el          	DET   	7	det
# siguiente   	siguiente   	ADJ   	0	root
# :           	:           	PUNCT 	9	punct
# Abdomen     	abdomen     	NOUN  	7	obj
# blando      	blando      	ADJ   	9	amod
# y           	y           	CCONJ 	12	cc
# depresible  	depresible  	ADJ   	10	conj
# ,           	,           	PUNCT 	15	punct
# no          	no          	ADV   	15	advmod
# doloroso    	doloroso    	ADJ   	9	amod
# ,           	,           	PUNCT 	15	punct
# no          	no          	ADV   	18	advmod
# megalias    	megalias    	NOUN  	9	conj
# ,           	,           	PUNCT 	20	punct
# Fosas       	Fosas       	PROPN 	9	conj
# renales     	renales     	PROPN 	20	flat
# libres      	libre       	PROPN 	20	flat
# indoloras   	indoloras   	PROPN 	20	flat
# .           	.           	PUNCT 	7	punct
#
# [Sentence 11]
# Genitales   	genital     	NOUN  	0	root
# externos    	externo     	ADJ   	1	amod
# sin         	sin         	ADP   	4	case
# signos      	signo       	NOUN  	1	nmod
# patológicos 	patológico  	ADJ   	4	amod
# .           	.           	PUNCT 	1	punct
#
# [Sentence 12]
# Tacto       	Tacto       	NOUN  	0	root
# rectal      	rectal      	ADJ   	1	amod
# compatible  	compatible  	ADJ   	1	amod
# con         	con         	ADP   	5	case
# HBP         	HBP         	PROPN 	3	nmod
# grado       	grado       	PROPN 	5	flat
# I-II        	I-II        	PROPN 	5	flat
# .           	.           	PUNCT 	1	punct
#
# [Sentence 13]
# Se          	él          	PRON  	2	expl:pass
# llevan      	llevar      	VERB  	0	root
# a           	a           	ADP   	4	case
# cabo        	cabo        	NOUN  	2	compound
# las         	el          	DET   	7	det
# siguientes  	siguiente   	ADJ   	7	amod
# EXPLORACIONES	exploración 	NOUN  	2	nsubj
# COMPLEMENTARIAS	complementario	ADJ   	7	amod
# :           	:           	PUNCT 	10	punct
# ANALISIS    	analisis    	NOUN  	7	appos
# :           	:           	PUNCT 	12	punct
# Glucemia    	Glucemia    	PROPN 	10	appos
# 145         	145         	NUM   	14	nummod
# mg/dl       	mg/dl       	NOUN  	12	appos
# ,           	,           	PUNCT 	16	punct
# Creatinina  	Creatinina  	PROPN 	12	conj
# 1.4         	1.4         	NUM   	18	nummod
# mg/dl       	mg/dl       	NOUN  	16	appos
# .           	.           	PUNCT 	2	punct
#
# [Sentence 14]
# Resto       	resto       	NOUN  	0	root
# de          	de          	ADP   	3	case
# parámetros  	parámetro   	NOUN  	1	nmod
# dentro      	dentro      	ADV   	1	advmod
# de          	de          	ADP   	7	case
# la          	el          	DET   	7	det
# normalidad  	normalidad  	NOUN  	4	obl
# .           	.           	PUNCT 	1	punct
#
# [Sentence 15]
# CITOLOGIA   	citologia   	NOUN  	0	root
# URINARIA    	URINARIA    	PROPN 	1	appos
# :           	:           	PUNCT 	4	punct
# Compatible  	Compatible  	PROPN 	1	appos
# con         	con         	ADP   	6	case
# carcinoma   	carcinoma   	NOUN  	4	nmod
# de          	de          	ADP   	8	case
# células     	célula      	NOUN  	6	nmod
# transicionales	transicional	ADJ   	8	amod
# de          	de          	ADP   	12	case
# bajo        	bajo        	ADP   	12	case
# grado       	grado       	NOUN  	8	nmod
# .           	.           	PUNCT 	1	punct
#
# [Sentence 16]
# PIELOGRAFIA 	PIELLGGAFIA 	PROPN 	0	root
# DESCENDENTE 	DESCENDENTE 	ADJ   	1	amod
# a           	a           	ADP   	6	case
# traves      	trave       	NOUN  	3	fixed
# de          	de          	ADP   	3	fixed
# Nefrostomia 	Nefrostomia 	PROPN 	1	nmod
# :           	:           	PUNCT 	8	punct
# Defecto     	Defecto     	PROPN 	1	appos
# de          	de          	ADP   	10	case
# replección  	replección  	NOUN  	8	nmod
# a           	a           	ADP   	12	case
# nivel       	nivel       	NOUN  	8	nmod
# de          	de          	ADP   	14	case
# uréter      	uréter      	NOUN  	12	nmod
# sacro-ilíaco	sacro-ilíaco	ADJ   	14	amod
# derecho     	derecho     	ADJ   	14	amod
# de          	de          	ADP   	20	case
# aproximadamente	aproximadamente	ADV   	20	advmod
# 20          	20          	NUM   	20	nummod
# mm          	mm          	NOUN  	16	nmod
# de          	de          	ADP   	22	case
# longitud    	longitud    	NOUN  	20	nmod
# ,           	,           	PUNCT 	25	punct
# con         	con         	ADP   	25	case
# signos      	signo       	NOUN  	8	nmod
# de          	de          	ADP   	27	case
# infiltración	infiltración	NOUN  	25	nmod
# de          	de          	ADP   	30	case
# la          	el          	DET   	30	det
# pared       	pared       	NOUN  	27	nmod
# .           	.           	PUNCT 	1	punct
#
# [Sentence 17]
# ESTUDIO     	estudio     	NOUN  	0	root
# FUNCIONAL   	funcional   	ADJ   	1	amod
# DE          	de          	ADP   	4	case
# RIÑON       	RIÑON       	PROPN 	1	nmod
# DERECHO     	DERECHO     	ADJ   	4	amod
# :           	:           	PUNCT 	7	punct
# Aclaramiento	aclaramiento	NOUN  	1	appos
# de          	de          	ADP   	9	case
# Creatinina  	Creatinina  	PROPN 	7	nmod
# inferior    	inferior    	PROPN 	9	flat
# a           	a           	ADP   	13	case
# 5           	5           	NUM   	13	nummod
# ml/minuto   	ml/minuto   	NOUN  	7	nmod
# .           	.           	PUNCT 	1	punct
#
# [Sentence 18]
# TAC         	TAC         	PROPN 	0	root
# ABDOMINO-PELVICO	ABDOMINO-PELVICO	PROPN 	1	flat
# :           	:           	PUNCT 	4	punct
# Aneurisma   	Aneurisma   	PROPN 	1	flat
# de          	de          	ADP   	6	case
# Aorta       	Aorta       	PROPN 	4	flat
# infrarrenal 	infrarrenal 	PROPN 	6	flat
# .           	.           	PUNCT 	1	punct
#
# [Sentence 19]
# Atrofia     	atrofia     	NOUN  	0	root
# hidronefrótica	hidronefrótico	ADJ   	1	amod
# de          	de          	ADP   	4	case
# riñón       	riñón       	NOUN  	1	nmod
# derecho     	derecho     	ADJ   	4	amod
# ,           	,           	PUNCT 	8	punct
# sin         	sin         	ADP   	8	mark
# visualizar  	visualizar  	VERB  	1	acl
# se          	él          	PRON  	8	expl:pv
# imágenes    	imagen      	NOUN  	8	obj
# endoluminales	endoluminal 	ADJ   	10	amod
# intraureterales	intraureteral	ADJ   	10	amod
# .           	.           	PUNCT 	1	punct
#
# [Sentence 20]
# Dudosas     	dudoso      	ADJ   	2	amod
# adenopatías 	adenopatía  	NOUN  	0	root
# paravesicales	paravesical 	ADJ   	2	amod
# .           	.           	PUNCT 	2	punct
#
# [Sentence 21]
# Ante        	ante        	ADP   	3	case
# estos       	este        	DET   	3	det
# hallazgos   	hallazgo    	NOUN  	18	obl
# y           	y           	CCONJ 	6	cc
# la          	el          	DET   	6	det
# sospecha    	sospecha    	NOUN  	3	conj
# de          	de          	ADP   	8	case
# tumor       	tumor       	NOUN  	6	nmod
# de          	de          	ADP   	10	case
# vías        	vía         	NOUN  	8	nmod
# de          	de          	ADP   	12	case
# uréter      	uréter      	NOUN  	10	nmod
# derecho     	derecho     	ADJ   	12	amod
# ,           	,           	PUNCT 	3	punct
# el          	el          	DET   	16	det
# paciente    	paciente    	NOUN  	18	nsubj
# es          	ser         	AUX   	18	aux
# intervenido 	intervenir  	VERB  	0	root
# quirúrgicamente	quirúrgicamente	ADV   	18	advmod
# practicando 	practicar   	VERB  	18	advcl
# se          	él          	PRON  	20	expl:pv
# nefroureterectomía	nefroureterectomía	NOUN  	20	obj
# radical     	radical     	ADJ   	22	amod
# derecha     	derecho     	ADJ   	22	amod
# con         	con         	ADP   	26	case
# evolución   	evolución   	NOUN  	20	obl
# postoperatoria	postoperatorio	ADJ   	26	amod
# satisfactoria	satisfactorio	ADJ   	26	amod
# .           	.           	PUNCT 	18	punct
#
# [Sentence 22]
# El          	el          	DET   	2	det
# dictamen    	dictamen    	NOUN  	8	nsubj
# histopatológico	histopatológico	ADJ   	2	amod
# de          	de          	ADP   	6	case
# la          	el          	DET   	6	det
# pieza       	pieza       	NOUN  	2	nmod
# nos         	yo          	PRON  	8	obj
# informa     	informar    	VERB  	0	root
# de          	de          	ADP   	10	case
# pielonefritis	pielonefritis	NOUN  	8	obj
# crónica     	crónica     	ADJ   	10	amod
# y           	y           	CCONJ 	13	cc
# cambios     	cambio      	NOUN  	10	conj
# de          	de          	ADP   	15	case
# arteriosclerosis	arteriosclerosis	NOUN  	13	nmod
# ,           	,           	PUNCT 	19	punct
# así         	así         	ADV   	19	cc
# como        	como        	SCONJ 	17	fixed
# lesión      	lesión      	NOUN  	10	conj
# inflamatoria	inflamatorio	ADJ   	19	amod
# ureteral    	ureteral    	ADJ   	19	amod
# que         	que         	PRON  	23	nsubj
# oblitera    	obliterar   	VERB  	19	acl
# la          	el          	DET   	25	det
# luz         	luz         	NOUN  	23	obj
# con         	con         	ADP   	27	case
# infiltrado  	infiltrado  	NOUN  	25	nmod
# de          	de          	ADP   	29	case
# linfocitos  	linfocito   	NOUN  	27	nmod
# en          	en          	ADP   	31	case
# capas       	capa        	NOUN  	27	nmod
# musculares  	muscular    	ADJ   	31	amod
# ,           	,           	PUNCT 	34	punct
# erosión     	erosión     	NOUN  	27	conj
# de          	de          	ADP   	36	case
# urotelio    	urotelio    	NOUN  	34	nmod
# y           	y           	CCONJ 	38	cc
# presencia   	presencia   	NOUN  	27	conj
# de          	de          	ADP   	40	case
# Actinomices 	Actinomices 	PROPN 	38	nmod
# .           	.           	PUNCT 	8	punct
#
# [Sentence 23]
# Tras        	tras        	ADP   	3	case
# 9           	9           	NUM   	3	nummod
# años        	año         	NOUN  	9	obl
# de          	de          	ADP   	5	case
# seguimiento 	seguimiento 	NOUN  	3	nmod
# ,           	,           	PUNCT 	3	punct
# el          	el          	DET   	8	det
# paciente    	paciente    	NOUN  	9	nsubj
# mantiene    	mantener    	VERB  	0	root
# una         	uno         	DET   	11	det
# función     	función     	NOUN  	9	obj
# renal       	renal       	ADJ   	11	amod
# aceptable   	aceptable   	ADJ   	11	amod
# (           	(           	PUNCT 	15	punct
# Creatinina  	Creatinina  	PROPN 	11	appos
# sérica      	sérico      	ADJ   	15	amod
# 2.1         	2.1         	NUM   	15	appos
# mg/dl       	mg/dl       	NOUN  	15	compound
# )           	)           	PUNCT 	15	punct
# y           	y           	CCONJ 	22	cc
# es          	ser         	AUX   	22	aux
# controlado  	controlar   	VERB  	9	conj
# por         	por         	ADP   	24	case
# HBP         	HBP         	PROPN 	22	obj
# sintomática 	sintomático 	ADJ   	24	amod
# .           	.           	PUNCT 	9	punct

# %%
print("Mention text\tType\tStart-End")
for ent in es_doc.ents:
    print("{}\t{}\t{}-{}".format(ent.text, ent.type, ent.start_char, ent.end_char))
# Out:
# Mention text	Type	Start-End
# Consultas Externas	MISC	31-49
# U.I.V.	MISC	263-269
# U.I.V.	ORG	461-467
# HTA	MISC	569-572
# PIELOGRAFIA DESCENDENTE	MISC	1148-1171
# Nefrostomia	ORG	1184-1195
# TAC	ORG	1424-1427
# Actinomices	MISC	2069-2080
# HBP	ORG	2210-2213

# %%
word = es_doc.sentences[0].words[0]
print(word)
# Out:
# {
#   "id": 1,
#   "text": "Varón",
#   "lemma": "varón",
#   "upos": "NOUN",
#   "xpos": "NOUN",
#   "feats": "Gender=Masc|Number=Sing",
#   "head": 0,
#   "deprel": "root",
#   "misc": "start_char=0|end_char=5"
# }

# %%
stanza.download('en', package='mimic', processors={'ner': 'i2b2'})
nlp = stanza.Pipeline('en', package='mimic', processors={'ner': 'i2b2'})
doc = nlp(page.text)
doc.sentences[0].print_dependencies()
# Out:
# ('Varón', 0, 'root')
# ('de', 1, 'flat')
# ('66', 4, 'nummod')
# ('años', 5, 'compound')
# ('controlado', 6, 'compound')
# ('en', 1, 'list')
# ('Consultas', 6, 'flat')
# ('Externas', 6, 'flat')
# ('por', 10, 'goeswith')
# ('hipertrofia', 13, 'compound')
# ('benigna', 13, 'goeswith')
# ('de', 13, 'goeswith')
# ('próstata', 6, 'appos')
# ('.', 1, 'punct')

# %%
for ent in doc.entities:
    print(f'{ent.text}\t{ent.type}')
# Out:
# hematuria	PROBLEM
# Diabetes Mellitus tipo II	PROBLEM
# Aneurisma carotídeo intracerebral sin secuelas	PROBLEM
# La exploración física	TEST
# doloroso	PROBLEM
# megalias	PROBLEM
# Glucemia	TEST
# Creatinina	TEST
# Compatible con carcinoma	PROBLEM
# a nivel de uréter sacro-ilíaco derecho	TREATMENT
# Aclaramiento de Creatinina inferior	TREATMENT
# Aneurisma	PROBLEM
# arteriosclerosis	PROBLEM
# ureteral que	PROBLEM
# Creatinina	TEST
# sérica	TEST
# HBP sintomática	PROBLEM

# %%
stanza.download('en', package='craft', processors={'ner': 'i2b2'})
nlp = stanza.Pipeline('en', package='craft', processors={'ner': 'i2b2'})
doc = nlp(page.text)
for ent in doc.entities:
    print(f'{ent.text}\t{ent.type}')
# Out:
# hematuria	PROBLEM
# Diabetes Mellitus tipo II	PROBLEM
# Aneurisma carotídeo intracerebral sin secuelas	PROBLEM
# La exploración física	TEST
# doloroso	PROBLEM
# megalias	PROBLEM
# Glucemia	TEST
# Creatinina	TEST
# Compatible con carcinoma	PROBLEM
# a nivel de uréter sacro-ilíaco derecho	TREATMENT
# Aclaramiento de Creatinina inferior	TREATMENT
# Aneurisma	PROBLEM
# arteriosclerosis	PROBLEM
# ureteral que	PROBLEM
# Creatinina	TEST
# sérica	TEST
# HBP sintomática	PROBLEM

# %%
# !pip install googletrans==3.1.0a0
# Out:
# Requirement already satisfied: googletrans==3.1.0a0 in /usr/local/lib/python3.7/dist-packages (3.1.0a0)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.7/dist-packages (from googletrans==3.1.0a0) (0.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2020.12.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.2.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (0.9.1)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.4.0)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2020.12.22)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.7/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.7/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.7/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.0.0)

# %%
from googletrans import Translator

translator = Translator()
translation = translator.translate(page.text, src='es', dest='en')

# %%
page.text
# Out:
# 'Varón de 66 años controlado en Consultas Externas por hipertrofia benigna de próstata. Presenta episodios de hematuria monosintomática autolimitada y urinocultivos negativos. En estudio ecográfico se observa ureteropielocaliectasia grado II de riñón derecho y en U.I.V. se objetiva anulación funcional de riñón derecho, motivo por el cuál, se practica nefrostomia percutánea derecha, que confirma el hallazgo urográfico. Ocho meses antes, est:udio ecográfico y U.I.V. sin hallazgos patológicos.\n\nEntre sus antecedentes personales cabe destacar: sin alergias conocidas. HTA. Diabetes Mellitus tipo II. Miocardiopatía hipertrófica. Aneurisma carotídeo intracerebral sin secuelas.\nLa exploración física practicada es la siguiente: Abdomen blando y depresible, no doloroso, no megalias, Fosas renales libres indoloras. Genitales externos sin signos patológicos. Tacto rectal compatible con HBP grado I-II. Se llevan a cabo las siguientes EXPLORACIONES COMPLEMENTARIAS:\nANALISIS: Glucemia 145 mg/dl, Creatinina 1.4 mg/dl. Resto de parámetros dentro de la normalidad.\nCITOLOGIA URINARIA: Compatible con carcinoma de células transicionales de bajo grado.\nPIELOGRAFIA DESCENDENTE a traves de Nefrostomia: Defecto de replección a nivel de uréter sacro-ilíaco derecho de aproximadamente 20 mm de longitud, con signos de infiltración de la pared.\n\nESTUDIO FUNCIONAL DE RIÑON DERECHO: Aclaramiento de Creatinina inferior a 5 ml/minuto.\nTAC ABDOMINO-PELVICO: Aneurisma de Aorta infrarrenal. Atrofia hidronefrótica de riñón derecho, sin visualizarse imágenes endoluminales intraureterales. Dudosas adenopatías paravesicales.\nAnte estos hallazgos y la sospecha de tumor de vías de uréter derecho, el paciente es intervenido quirúrgicamente practicándose nefroureterectomía radical derecha con evolución postoperatoria satisfactoria. El dictamen histopatológico de la pieza nos informa de pielonefritis crónica y cambios de arteriosclerosis, así como lesión inflamatoria ureteral que oblitera la luz con infiltrado de linfocitos en capas musculares, erosión de urotelio y presencia de Actinomices. Tras 9 años de seguimiento, el paciente mantiene una función renal aceptable (Creatinina sérica 2.1 mg/dl ) y es controlado por HBP sintomática.\n'

# %%
translation.text
# Out:
# '66-year-old man controlled in Outpatient Clinics for benign prostate hypertrophy. He presents with episodes of self-limited monosymptomatic hematuria and negative urine cultures. An ultrasound study shows grade II ureteropyelocaliectasis of the right kidney and in IVU. Functional cancellation of the right kidney was observed, which is why a right percutaneous nephrostomy was performed, which confirmed the urographic finding. Eight months before, he was studying ultrasound and U.I.V. without pathological findings.\n\nHis personal history includes: no known allergies. HTA. Type II diabetes mellitus. Hypertrophic cardiomyopathy. Intracerebral carotid aneurysm without sequelae.\nThe physical examination performed is as follows: soft and depressible abdomen, not painful, not megaly, painless free renal fossae. External genitalia without pathological signs. Rectal examination compatible with BPH grade I-II. The following COMPLEMENTARY EXAMINATIONS are carried out:\nANALYSIS: Glucose 145 mg / dl, Creatinine 1.4 mg / dl. Rest of parameters within normality.\nURINARY CYTOLOGY: Compatible with low-grade transitional cell carcinoma.\nDESCENDING PYELOGRAPHY through Nephrostomy: filling defect at the level of the right sacro-iliac ureter of approximately 20 mm in length, with signs of infiltration of the wall.\n\nFUNCTIONAL STUDY OF THE RIGHT KIDNEY: Creatinine clearance less than 5 ml / minute.\nABDOMINO-PELVIC CAT: Infrarenal Aortic aneurysm. Hydronephrotic atrophy of the right kidney, without visualizing intraureteral endoluminal images. Doubtful paravesical lymphadenopathy.\nGiven these findings and the suspicion of a tumor of the right ureteric tract, the patient underwent surgery and performed a right radical nephroureterectomy with a satisfactory postoperative evolution. The histopathological opinion of the specimen informs us of chronic pyelonephritis and changes in arteriosclerosis, as well as an inflammatory ureteral lesion that obliterates the lumen with infiltrate of lymphocytes in muscular layers, erosion of the urothelium and the presence of Actinomyces. After 9 years of follow-up, the patient maintains acceptable renal function (serum creatinine 2.1 mg / dl) and is controlled for symptomatic BPH.'

# %%
stanza.download('en', package='craft', processors={'ner': 'i2b2'})
nlp = stanza.Pipeline('en', package='craft', processors={'ner': 'i2b2'})
doc = nlp(translation.text)
for ent in doc.entities:
    print(f'{ent.text}\t{ent.type}')
# Out:
# benign prostate hypertrophy	PROBLEM
# self-limited monosymptomatic hematuria	PROBLEM
# urine cultures	TEST
# An ultrasound study	TEST
# grade II ureteropyelocaliectasis of the right kidney	PROBLEM
# IVU	TEST
# a right percutaneous nephrostomy	TREATMENT
# studying ultrasound	TEST
# pathological findings	PROBLEM
# known allergies	PROBLEM
# Type II diabetes mellitus	PROBLEM
# Hypertrophic cardiomyopathy	PROBLEM
# Intracerebral carotid aneurysm	PROBLEM
# sequelae	PROBLEM
# The physical examination	TEST
# soft and depressible abdomen	PROBLEM
# painful	PROBLEM
# megaly	PROBLEM
# painless free renal fossae	PROBLEM
# pathological signs	PROBLEM
# Rectal examination	TEST
# BPH	PROBLEM
# The following COMPLEMENTARY EXAMINATIONS	TEST
# Glucose	TEST
# Creatinine	TEST
# Rest of parameters	TEST
# URINARY CYTOLOGY	TEST
# low-grade transitional cell carcinoma	PROBLEM
# DESCENDING PYELOGRAPHY	TEST
# Nephrostomy	TREATMENT
# filling defect	PROBLEM
# infiltration of the wall	PROBLEM
# Creatinine clearance	TEST
# Infrarenal Aortic aneurysm	PROBLEM
# Hydronephrotic atrophy of the right kidney	PROBLEM
# visualizing intraureteral endoluminal images	TEST
# Doubtful paravesical lymphadenopathy	PROBLEM
# a tumor of the right ureteric tract	PROBLEM
# surgery	TREATMENT
# a right radical nephroureterectomy	TREATMENT
# the specimen	TEST
# chronic pyelonephritis	PROBLEM
# changes in arteriosclerosis	PROBLEM
# an inflammatory ureteral lesion	PROBLEM
# infiltrate of lymphocytes in muscular layers	PROBLEM
# erosion of the urothelium	PROBLEM
# Actinomyces	PROBLEM
# serum creatinine	TEST
# symptomatic BPH	PROBLEM

# %%
stanza.download('en', package='mimic', processors={'ner': 'i2b2'})
nlp = stanza.Pipeline('en', package='mimic', processors={'ner': 'i2b2'})
doc = nlp(translation.text)
for ent in doc.entities:
    print(f'{ent.text}\t{ent.type}')
# Out:
# benign prostate hypertrophy	PROBLEM
# self-limited monosymptomatic hematuria	PROBLEM
# urine cultures	TEST
# An ultrasound study	TEST
# grade II ureteropyelocaliectasis of the right kidney	PROBLEM
# IVU	TEST
# a right percutaneous nephrostomy	TREATMENT
# studying ultrasound	TEST
# pathological findings	PROBLEM
# known allergies	PROBLEM
# Type II diabetes mellitus	PROBLEM
# Hypertrophic cardiomyopathy	PROBLEM
# Intracerebral carotid aneurysm	PROBLEM
# sequelae	PROBLEM
# The physical examination	TEST
# soft and depressible abdomen	PROBLEM
# painful	PROBLEM
# megaly	PROBLEM
# painless free renal fossae	PROBLEM
# pathological signs	PROBLEM
# Rectal examination	TEST
# BPH	PROBLEM
# Glucose	TEST
# Creatinine	TEST
# URINARY CYTOLOGY	TEST
# low-grade transitional cell carcinoma	PROBLEM
# DESCENDING PYELOGRAPHY	TEST
# Nephrostomy	TREATMENT
# filling defect	PROBLEM
# infiltration of the wall	PROBLEM
# Creatinine clearance	TEST
# Infrarenal Aortic aneurysm	PROBLEM
# Hydronephrotic atrophy of the right kidney	PROBLEM
# visualizing intraureteral endoluminal images	TEST
# Doubtful paravesical lymphadenopathy	PROBLEM
# a tumor of the right ureteric tract	PROBLEM
# surgery	TREATMENT
# a right radical nephroureterectomy	TREATMENT
# the specimen	TEST
# chronic pyelonephritis	PROBLEM
# changes in arteriosclerosis	PROBLEM
# an inflammatory ureteral lesion	PROBLEM
# infiltrate of lymphocytes in muscular layers	PROBLEM
# erosion of the urothelium	PROBLEM
# Actinomyces	PROBLEM
# serum creatinine	TEST
# symptomatic BPH	PROBLEM
